# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import os

# File to Load (Remember to Change These)
file = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
file_df = pd.read_csv(file)
file_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
file_df.isnull().any()
# Out:
# Purchase ID    False
# SN             False
# Age            False
# Gender         False
# Item ID        False
# Item Name      False
# Price          False
# dtype: bool

# %%
total_players = file_df["SN"].nunique()
total_players
# Out:
# 576

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
pd.DataFrame({"Total Players": [total_players]})
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_items = file_df["Item ID"].nunique()
unique_items

avg_price = file_df["Price"].mean()
avg_price

purchase_num = file_df["Purchase ID"].count()
purchase_num

revenue = file_df["Price"].sum()
revenue
# Out:
# 2379.77

# %%
summary_df = pd.DataFrame({"Number of Unique Items": [unique_items],
                          "Average Price": [avg_price],
                          "Number of Purchases": [purchase_num],
                          "Total Revenue": [revenue]})
summary_df["Average Price"] = summary_df["Average Price"].map("${:,.2f}".format)
summary_df["Total Revenue"] = summary_df["Total Revenue"].map("${:,.2f}".format)
summary_df.head()
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     179         $3.05                  780     $2,379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
file_df2 = file_df.loc[:,["Gender", "SN", "Age"]].drop_duplicates()

total_df = file_df2["Gender"].value_counts()
total_df
# Out:
# Male                     484
# Female                    81
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
gender_total_df = file_df2["Gender"].count()
gender_total_df
# Out:
# 576

# %%
percentage_df = (total_df/gender_total_df)*100
percentage_df
# Out:
# Male                     84.027778
# Female                   14.062500
# Other / Non-Disclosed     1.909722
# Name: Gender, dtype: float64

# %%
gender_df = pd.DataFrame({"Count": total_df, "Percentage": percentage_df})
gender_df["Percentage"] = gender_df["Percentage"].map("{:,.2f}%".format)
gender_df
# Out:
#                        Count Percentage
# Male                     484     84.03%
# Female                    81     14.06%
# Other / Non-Disclosed     11      1.91%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
female_df = file_df[file_df["Gender"] == "Female"]
female_df.head()

male_df = file_df[file_df["Gender"] == "Male"]
male_df.head()

others_df = file_df[file_df["Gender"] == "Other / Non-Disclosed"]
others_df.head()
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 9              9   Chanosian48   35  Other / Non-Disclosed      136
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 82            82    Haerithp41   16  Other / Non-Disclosed      160
# 111          111      Sundim98   21  Other / Non-Disclosed       41
# 228          228   Jiskirran77   20  Other / Non-Disclosed       80
#
#                         Item Name  Price
# 9    Ghastly Adamantite Protector   3.58
# 22                  Warped Fetish   3.81
# 82                     Azurewrath   4.40
# 111                         Orbit   4.75
# 228                     Dreamsong   3.39

# %%
grouped_gender = file_df.groupby(["Gender"])
print(grouped_gender)
grouped_gender.head()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f8a1edee430>
#      Purchase ID             SN  Age                 Gender  Item ID  \
# 0              0        Lisim78   20                   Male      108
# 1              1    Lisovynya38   40                   Male      143
# 2              2     Ithergue48   24                   Male       92
# 3              3  Chamassasya86   24                   Male      100
# 4              4      Iskosia90   23                   Male      131
# 9              9    Chanosian48   35  Other / Non-Disclosed      136
# 15            15      Lisassa64   21                 Female       98
# 18            18      Reunasu60   22                 Female       82
# 22            22   Siarithria38   38  Other / Non-Disclosed       24
# 38            38       Reulae52   10                 Female      116
# 41            41      Assosia88   20                 Female        7
# 55            55      Phaelap26   25                 Female       84
# 82            82     Haerithp41   16  Other / Non-Disclosed      160
# 111          111       Sundim98   21  Other / Non-Disclosed       41
# 228          228    Jiskirran77   20  Other / Non-Disclosed       80
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# 9                 Ghastly Adamantite Protector   3.58
# 15                 Deadline, Voice Of Subtlety   2.89
# 18                                     Nirvana   4.90
# 22                               Warped Fetish   3.81
# 38                     Renewed Skeletal Katana   4.18
# 41                Thorn, Satchel of Dark Souls   1.33
# 55                                  Arcane Gem   3.79
# 82                                  Azurewrath   4.40
# 111                                      Orbit   4.75
# 228                                  Dreamsong   3.39

# %%
avg_purchase = grouped_gender["Price"].mean()

total_purchase_by_gender = grouped_gender["Price"].sum()

purchase_count = grouped_gender["Purchase ID"].count()

avg_total_purchase_per_person = (total_purchase_by_gender / total_df)
avg_total_purchase_per_person
# Out:
# Female                   4.468395
# Male                     4.065372
# Other / Non-Disclosed    4.562727
# dtype: float64

# %%
purchase_analysis = pd.DataFrame({"Purchase Count": purchase_count,
                                 "Average Purchase Price": avg_purchase,
                                 "Total Purchase Value": total_purchase_by_gender,
                                 "Avg Total Purchase per Person": avg_total_purchase_per_person})
purchase_analysis
#question: why the avg. total purchase per person is wrong?
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Gender
# Female                               361.94                       4.468395
# Male                                1967.64                       4.065372
# Other / Non-Disclosed                 50.19                       4.562727

# %% [markdown]
# ## Age Demographics

# %%
bins = [0, 9, 14, 19, 24, 29, 34, 39, 100]

bins_name = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
file_df["Age Ranges"] = pd.cut(file_df["Age"], bins, labels=bins_name)
file_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Ranges
# 0    Extraction, Quickblade Of Trembling Hands   3.53      20-24
# 1                            Frenzied Scimitar   1.56        40+
# 2                                 Final Critic   4.88      20-24
# 3                                  Blindscythe   3.27      20-24
# 4                                         Fury   1.44      20-24
# ..                                         ...    ...        ...
# 775                                       Wolf   3.54      20-24
# 776                           Exiled Doomblade   1.63      20-24
# 777      Celeste, Incarnation of the Corrupted   3.46      20-24
# 778                               Final Critic   4.19        <10
# 779                                       Dawn   4.60      20-24
#
# [780 rows x 8 columns]

# %%
age_grouped = file_df.groupby(["Age Ranges"])
age_grouped

# %%
age_count = age_grouped["SN"].nunique()
#age_count
age_percent = (age_count / total_players) * 100
age_percent
# Out:
# Age Ranges
# <10       2.951389
# 10-14     3.819444
# 15-19    18.576389
# 20-24    44.791667
# 25-29    13.368056
# 30-34     9.027778
# 35-39     5.381944
# 40+       2.083333
# Name: SN, dtype: float64

# %%
age_df = pd.DataFrame({"Total Count": age_count,
                      "Percentage of Players": age_percent})
age_df["Percentage of Players"] = age_df["Percentage of Players"].map("{:.2f}%".format)
age_df
# Out:
#             Total Count Percentage of Players
# Age Ranges
# <10                  17                 2.95%
# 10-14                22                 3.82%
# 15-19               107                18.58%
# 20-24               258                44.79%
# 25-29                77                13.37%
# 30-34                52                 9.03%
# 35-39                31                 5.38%
# 40+                  12                 2.08%

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
avg_purchase_age = age_grouped["Price"].mean()

total_purchase_age = age_grouped["Price"].sum()

purchase_count_age = age_grouped["Purchase ID"].count()

avg_total_purchase_per_person_age = (total_purchase_age / age_count)

# %%
purchase_analysis_age = pd.DataFrame({"Purchase Count": purchase_count_age,
                                 "Average Purchase Price": avg_purchase_age,
                                 "Total Purchase Value": total_purchase_age,
                                 "Avg Total Purchase per Person": avg_total_purchase_per_person_age})
purchase_analysis_age["Average Purchase Price"] = purchase_analysis_age["Average Purchase Price"].map("${:,.2f}".format)
purchase_analysis_age["Total Purchase Value"] = purchase_analysis_age["Total Purchase Value"].map("${:,.2f}".format)
purchase_analysis_age["Avg Total Purchase per Person"] = purchase_analysis_age["Avg Total Purchase per Person"].map("${:,.2f}".format)

purchase_analysis_age
# Out:
#             Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                     23                  $3.35               $77.13
# 10-14                   28                  $2.96               $82.78
# 15-19                  136                  $3.04              $412.89
# 20-24                  365                  $3.05            $1,114.06
# 25-29                  101                  $2.90              $293.00
# 30-34                   73                  $2.93              $214.00
# 35-39                   41                  $3.60              $147.67
# 40+                     13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# 35-39                              $4.76
# 40+                                $3.19

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
spenders = file_df["SN"].value_counts()

grouped_spender = file_df.groupby(["SN"])
print(grouped_spender)

total_spender = grouped_spender["Price"].sum()
total_spender

purchase_count_spender = grouped_spender["Purchase ID"].count()
purchase_count_spender

avg_total_purchase_per_spender = (total_spender / purchase_count_spender)
avg_total_purchase_per_spender
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f82647ed1f0>
# SN
# Adairialis76     2.280000
# Adastirin33      4.480000
# Aeda94           4.910000
# Aela59           4.320000
# Aelaria33        1.790000
#                    ...
# Yathecal82       2.073333
# Yathedeu43       3.010000
# Yoishirrala98    4.580000
# Zhisrisu83       3.945000
# Zontibe81        2.676667
# Length: 576, dtype: float64

# %%
spenders_analysis = pd.DataFrame({"Purchase Count": purchase_count_spender,
                                 "Average Purchase Price": avg_total_purchase_per_spender,
                                 "Total Purchase Value": total_spender})

spenders_analysis["Average Purchase Price"] = spenders_analysis["Average Purchase Price"].map("${:,.2f}".format)
spenders_analysis["Total Purchase Value"] = spenders_analysis["Total Purchase Value"].map("${:,.2f}".format)

spenders_analysis.sort_values("Purchase Count", ascending=False)
# Out:
#               Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                  5                  $3.79               $18.96
# Iral74                     4                  $3.40               $13.62
# Idastidru52                4                  $3.86               $15.45
# Asur53                     3                  $2.48                $7.44
# Inguron55                  3                  $3.70               $11.11
# ...                      ...                    ...                  ...
# Hala31                     1                  $1.02                $1.02
# Haisurra41                 1                  $4.40                $4.40
# Hailaphos89                1                  $3.81                $3.81
# Haestyphos66               1                  $1.97                $1.97
# Iskosian40                 1                  $3.07                $3.07
#
# [576 rows x 3 columns]

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
items = file_df[["Item ID", "Item Name", "Price"]]

items_grouped = file_df.groupby(["Item ID", "Item Name"])
items_grouped

purchased_items = items_grouped["Item ID"].count()
purchased_items

items_price = items_grouped["Price"].mean()
items_price

items_total_price = purchased_items * items_price
items_total_price.sort_values()
# Out:
# Item ID  Item Name
# 42       The Decapitator                                  1.75
# 104      Gladiator's Glaive                               1.93
# 126      Exiled Mithril Longsword                         2.00
# 125      Whistling Mithril Warblade                       2.00
# 28       Flux, Destroyer of Due Diligence                 2.12
#                                                          ...
# 103      Singed Scalpel                                  34.80
# 145      Fiery Glass Crusader                            41.22
# 82       Nirvana                                         44.10
# 178      Oathbreaker, Last Hope of the Breaking Storm    50.76
# 92       Final Critic                                    59.99
# Length: 179, dtype: float64

# %%
items_analysis = pd.DataFrame({"Purchase Count": purchased_items,
                                 "Item Price": items_price,
                                 "Total Purchase Value": items_total_price})


#items_analysis["Item Price"] = items_analysis["Item Price"].map("${:,.2f}".format)
#items_analysis["Total Purchase Value"] = items_analysis["Total Purchase Value"].map("${:,.2f}".format)

sort_by_count = items_analysis.sort_values("Purchase Count", ascending=False)

sort_by_count.style.format({"Item Price":"${:,.2f}", "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1f" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow0_col0" class="data row0 col0" >13</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow1_col0" class="data row1 col0" >12</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row2" class="row_heading level0 row2" >145</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow2_col0" class="data row2 col0" >9</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow2_col1" class="data row2 col1" >$4.58</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow2_col2" class="data row2 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row3" class="row_heading level0 row3" >132</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row3" class="row_heading level1 row3" >Persuasion</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow3_col1" class="data row3 col1" >$3.22</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow3_col2" class="data row3 col2" >$28.99</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row4" class="row_heading level0 row4" >108</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row4" class="row_heading level1 row4" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow4_col0" class="data row4 col0" >9</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow4_col1" class="data row4 col1" >$3.53</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow4_col2" class="data row4 col2" >$31.77</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row5" class="row_heading level0 row5" >82</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row5" class="row_heading level1 row5" >Nirvana</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow5_col0" class="data row5 col0" >9</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow5_col1" class="data row5 col1" >$4.90</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow5_col2" class="data row5 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row6" class="row_heading level0 row6" >75</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row6" class="row_heading level1 row6" >Brutality Ivory Warmace</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow6_col0" class="data row6 col0" >8</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow6_col1" class="data row6 col1" >$2.42</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow6_col2" class="data row6 col2" >$19.36</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row7" class="row_heading level0 row7" >103</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row7" class="row_heading level1 row7" >Singed Scalpel</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow7_col0" class="data row7 col0" >8</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow7_col1" class="data row7 col1" >$4.35</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow7_col2" class="data row7 col2" >$34.80</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row8" class="row_heading level0 row8" >34</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row8" class="row_heading level1 row8" >Retribution Axe</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow8_col0" class="data row8 col0" >8</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow8_col1" class="data row8 col1" >$2.22</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow8_col2" class="data row8 col2" >$17.76</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row9" class="row_heading level0 row9" >37</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row9" class="row_heading level1 row9" >Shadow Strike, Glory of Ending Hope</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow9_col0" class="data row9 col0" >8</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow9_col1" class="data row9 col1" >$3.16</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow9_col2" class="data row9 col2" >$25.28</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row10" class="row_heading level0 row10" >19</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row10" class="row_heading level1 row10" >Pursuit, Cudgel of Necromancy</th>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow10_col0" class="data row10 col0" >8</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow10_col1" class="data row10 col1" >$1.02</td>
#                         <td id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1frow10_col2" class="data row10 col2" >$8.16</td>
#             </tr>
#             <tr>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel0_row11" class="row_heading level0 row11" >60</th>
#                         <th id="T_c18d6b84_e95e_11ea_8530_acbc32bdcb1flevel1_row11" class="ro

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
items_analysis2 = sort_by_count.sort_values("Total Purchase Value", ascending=False)
items_analysis2.style.format({"Item Price":"${:,.2f}", "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1f" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow0_col0" class="data row0 col0" >13</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow0_col1" class="data row0 col1" >$4.61</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow0_col2" class="data row0 col2" >$59.99</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row1" class="row_heading level0 row1" >178</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow1_col0" class="data row1 col0" >12</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow1_col1" class="data row1 col1" >$4.23</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow1_col2" class="data row1 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row2" class="row_heading level0 row2" >82</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row2" class="row_heading level1 row2" >Nirvana</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow2_col0" class="data row2 col0" >9</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow2_col1" class="data row2 col1" >$4.90</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow2_col2" class="data row2 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row3" class="row_heading level0 row3" >145</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row3" class="row_heading level1 row3" >Fiery Glass Crusader</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow3_col1" class="data row3 col1" >$4.58</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow3_col2" class="data row3 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow4_col0" class="data row4 col0" >8</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow4_col1" class="data row4 col1" >$4.35</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow4_col2" class="data row4 col2" >$34.80</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row5" class="row_heading level0 row5" >59</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row5" class="row_heading level1 row5" >Lightning, Etcher of the King</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow5_col0" class="data row5 col0" >8</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow5_col1" class="data row5 col1" >$4.23</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow5_col2" class="data row5 col2" >$33.84</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row6" class="row_heading level0 row6" >108</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row6" class="row_heading level1 row6" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow6_col0" class="data row6 col0" >9</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow6_col1" class="data row6 col1" >$3.53</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow6_col2" class="data row6 col2" >$31.77</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row7" class="row_heading level0 row7" >78</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row7" class="row_heading level1 row7" >Glimmer, Ender of the Moon</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow7_col0" class="data row7 col0" >7</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow7_col1" class="data row7 col1" >$4.40</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow7_col2" class="data row7 col2" >$30.80</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row8" class="row_heading level0 row8" >72</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row8" class="row_heading level1 row8" >Winter's Bite</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow8_col0" class="data row8 col0" >8</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow8_col1" class="data row8 col1" >$3.77</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow8_col2" class="data row8 col2" >$30.16</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row9" class="row_heading level0 row9" >132</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row9" class="row_heading level1 row9" >Persuasion</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow9_col0" class="data row9 col0" >9</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow9_col1" class="data row9 col1" >$3.22</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow9_col2" class="data row9 col2" >$28.99</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row10" class="row_heading level0 row10" >60</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row10" class="row_heading level1 row10" >Wolf</th>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow10_col0" class="data row10 col0" >8</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow10_col1" class="data row10 col1" >$3.54</td>
#                         <td id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1frow10_col2" class="data row10 col2" >$28.32</td>
#             </tr>
#             <tr>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel0_row11" class="row_heading level0 row11" >179</th>
#                         <th id="T_e90b15ee_e95e_11ea_8530_acbc32bdcb1flevel1_row11" class="row_heading level1 row11" >Wol
